# %%
print("vinay")
# Out:
# vinay

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
sum=a+b
print("sum of two numbers:",sum)
# Out:
# Enter a number:4
# Enter a number:8
# sum of two numbers: 12

# %%
a=input("enter your name:")
print(a)
print(a[0:3])
print(a[-2])
# Out:
# enter your name:vinay
# vinay
# vin
# a

# %%
#find area of the square
s=float(input("Enter the side of the square:"))
area=s*s
print("area of the square is",area )
# Out:
# Enter the side of the square:8
# area of the square is 64.0

# %%
#fing area of a right angled triangle
b=float(input("Enter the base:"))
h=float(input("Enter the height:"))
area=0.5*b*h
print("area of the right angled triangle is:",area)
# Out:
# Enter the base:6
# Enter the height:7
# area of the right angled triangle is: 21.0

# %%
#program to find simple interest
p=float(input("Enter the principal amt"))
y=float(input("Enter the no. of years:"))
r=float(input("Enter the rate of interest:"))
si=(p*y*r)/100
print("the simple interest is:",si)
# Out:
# Enter the principal amt1000
# Enter the no. of years:4
# Enter the rate of interest:6
# the simple interest is: 240.0

# %%
#find previous and next number of an integer
n=int(input("Enter the integer:"))
pn=n-1
nn=n+1
print("the previous number is:",pn) 
print("the next number is:",nn)
# Out:
# Enter the integer:5
# the previous number is: 4
# the next number is: 6
