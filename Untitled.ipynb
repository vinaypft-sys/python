# %%
mark=[5,4,4,6,3]
print(mark[0])
# Out:
# 5

# %%
mark=[23,42,23,23,43]
mark.append(50)
print(mark)
# Out:
# [23, 42, 23, 23, 43, 50]

# %%
rollno=(3,2,4,5,2)
print(rollno[2])
# Out:
# 4

# %%
s={3,4,2,3}
print(s)
# Out:
# {2, 3, 4}

# %%
d={"age":25, "name":"vinay","mark":60}
print(d["name"])
# Out:
# vinay

# %%
n="vinay"
print(n[0])
print(n[-1])
# Out:
# v
# y
